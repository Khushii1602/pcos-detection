# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:20px; padding:20px;">
#     <h2 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">POLYCYSTIC OVARY SYNDROME (PCOS): DIAGNOSTIC Project</h2>
# </div>
#
#
#
# ## Building A Classification Model
#
#
# #### By Elliot M Sithole
#
# **03/05/2024**

# %% [markdown]
# ![Profile](https://storage.googleapis.com/kagglesdsdata/datasets/4592106/7834554/profile.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20240313%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240313T142257Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h2 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Understanding PCOS</h2>
#     <p style="font-family: Arial, sans-serif; color:#34495E; font-size:16px; text-align:justify;">Polycystic Ovary Syndrome, commonly known as PCOS, is a complex hormonal disorder that has become increasingly prevalent among women of reproductive age. Understanding PCOS is crucial, as it lays the foundation for recognizing symptoms and seeking timely management of the condition.</p>
# </div>

# %% [markdown]
# ![Slide 1](https://storage.googleapis.com/kagglesdsdata/datasets/4592106/7834554/Slide1.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20240313%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240313T144057Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# ![Slide 2](https://storage.googleapis.com/kagglesdsdata/datasets/4592106/7834554/Slide2.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20240313%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240313T144141Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h2 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Table of Contents</h2>
#
# * **The Dataset**
# * **Importing Libraries**
# * **Loading data**
# * **Data Preprocessing**
# * **Exploratory Data Analysis**
# * **Model Building**

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h2 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">About the Dataset</h2>
#     <p style="font-family: Arial, sans-serif; color:#34495E; font-size:16px; text-align:justify;">Polycystic Ovary Syndrome, The dataset contains all physical and clinical parameters to determine PCOS and infertility related issues and the
# data was collected from 10 different hospital across Kerala,India.</p>
# </div>

# %% [markdown]
# For more information on PCOS visit ([here](https://www.kaggle.com/datasets/prasoonkottarathil/polycystic-ovary-syndrome-pcos))

# %% [markdown]
# * Patient File No. : This is the report number which has data for a particular patient
# * PCOS : Polycystic ovary syndrome (PCOS) is a hormonal disorder common among women of reproductive age, we would like to determine whether the patient has this syndrome or not
# * Age (yrs) : Age of patient in years
# * Weight (Kg) : Weight of patient in kg
# * Height(Cm) : Height of patient in centimeter
# * BMI : Body mass index of the patient
# * Blood Group : Blood Group of the patient A+ = 11, A- = 12, B+ = 13, B- = 14, O+ =15, O- = 16, AB+ =17, AB- = 18 (total 8 blood groups)
# * Pulse rate(bpm) : It is the heart rate of patient in beats per minute. Resting heart rate for adults ranges from 60 to 100 beats per minute
# * RR (breaths/min) : It is the respiration rate. Normal respiration rates for an adult person at rest range from 12 to 16 breaths per minute.
# * Hb(g/dl) : Hemoglobin levels in gram per deciliter. For women, a normal level ranges between 12.3 gm/dL and 15.3 gm/dL.
# * Cycle(R/I) : ....
# * Cycle length(days) : This represents length of menstrual cycle. The length of the menstrual cycle varies from woman to woman, but the average is to have periods every 28 days.
# * Marraige Status (Yrs) : Years of marriage
# * Pregnant(Y/N) : If the patient is pregnant
# * No. of aborptions : No. of aborptions, if any. There are total 541 values out of which 437 patients never had any abortions.
# * I beta-HCG(mIU/mL) : this is case 1 of beta hcg
# * II beta-HCG(mIU/mL) : this is case 2 of beta hcg (please note: An beta hCG level of less than 5 mIU/mL is considered negative for pregnancy, and anything above 25 mIU/mL is considered positive for pregnancy) (also the unit mIU/mL is mili International Units per miliLiter)
# * FSH(mIU/mL) : Its full form is Follicle-stimulating hormone. During puberty: it ranges from 0.3 to 10.0 mIU/mL (0.3 to 10.0 IU/L) Women who are still menstruating: 4.7 to 21.5 mIU/mL (4.5 to 21.5 IU/L) After menopause: 25.8 to 134.8 mIU/mL (25.8 to 134.8 IU/L)
# * LH(mIU/mL) : It is Luteinizing Hormone.
# * FSH/LH : Ratio of FSH and LH
# * Hip(inch) : Hip size in inches
# * Waist(inch) : Waist Size in inches
# * Waist:Hip Ratio : Waist by hip ratio
# * TSH (mIU/L) : It is thyroid stimulating hormone. Normal values are from 0.4 to 4.0 mIU/L
# * AMH(ng/mL) : It is Anti-Mullerian Hormone.
# * PRL(ng/mL) : This represents Prolactin levels.
# * Vit D3 (ng/mL): Vitamin D levels. Normal vitamin D levels in the blood are 20 ng/ml or above for adults.
# * PRG(ng/mL): Progesterone levels
# * RBS(mg/dl): This value is obtained by doing Random Blood Sugar (RBS) Test.
# * Weight gain(Y/N): Is there been a weight gain
# * hair growth(Y/N): Is there been a hair growth
# * Skin darkening (Y/N): Skin darkening issues
# * Hair loss(Y/N): hair loss issues
# * Pimples(Y/N): pimples issues
# * Fast food (Y/N): is fast food part of you diet
# * Reg.Exercise(Y/N): do you do exercises on a regular basis
# * BP _Systolic (mmHg): Systolic blood pressure, measures the pressure in your arteries when your heart beats.
# * BP _Diastolic (mmHg): Diastolic blood pressure, measures the pressure in your arteries when your heart rests between beats.
# * Follicle No. (L): Follicles number in the left side
# * Follicle No. (R): Follicles number in the right side
# * Avg. F size (L) (mm): Average Follicle size in the left side in mm
# * Avg. F size (R) (mm): Average Follicle size in the right side in mm
# * Endometrium (mm): Size of Endometrium in mm

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h2 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Importing Libraries</h2>

# %%
# get important libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h3 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Loading Data....</h3>

# %%
import pandas as pd
pcos_inf= pd.read_csv("C:/Users/KHUSHI/OneDrive/Desktop/PCOS_infertility.csv")
pcos_inf.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)    I   beta-HCG(mIU/mL)  \
# 0       1             10001           0                    1.99
# 1       2             10002           0                   60.80
# 2       3             10003           1                  494.08
# 3       4             10004           0                    1.99
# 4       5             10005           0                  801.45
#
#    II    beta-HCG(mIU/mL) AMH(ng/mL)
# 0                    1.99       2.07
# 1                    1.99       1.53
# 2                  494.08       6.63
# 3                    1.99       1.22
# 4                  801.45       2.26

# %% [markdown]
# # Assistant
# The selected code reads a CSV file named "PCOS_infertility.csv" from the specified file path "C:/Users/KHUSHI/Downloads/archive (2).zip/". It then displays the first few rows of the DataFrame using the `head()` function.

# %%
import pandas as pd
pcos_non_inf= pd.read_excel("C:/Users/KHUSHI/Downloads/PCOS_data_without_infertility.xlsx", sheet_name="Full_new")
pcos_non_inf.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1   NaN           15                74                20  ...
# 2   NaN           11                72                18  ...
# 3   NaN           13                72                20  ...
# 4   NaN           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                  0                  110
# 1              0.0                  0                  120
# 2              1.0                  0                  120
# 3              0.0                  0                  120
# 4              0.0                  0                  120
#
#    BP _Diastolic (mmHg)  Follicle No. (L)  Follicle No. (R)  \
# 0                    80                 3                 3
# 1                    70                 3                 5
# 2                    80                13                15
# 3                    70                 2                 2
# 4                    80                 3                 4
#
#    Avg. F size (L) (mm) Avg. F size (R) (mm)  Endometrium (mm)  Unnamed: 44
# 0                  18.0                 18.0               8.5          NaN
# 1                  15.0                 14.0               3.7          NaN
# 2                  18.0                 20.0              10.0          NaN
# 3                  15.0                 14.0               7.5          NaN
# 4                  16.0                 14.0               7.0          NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h3 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Data Preprocessing</h3>

# %%
import pandas as pd

# Load the data into a DataFrame
pcos_inf = pd.read_csv("C:/Users/KHUSHI/OneDrive/Desktop/PCOS_infertility.csv")

# Check information about the DataFrame
pcos_inf.info()
df0= pcos_inf
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3     I   beta-HCG(mIU/mL)  541 non-null    float64
#  4   II    beta-HCG(mIU/mL)  541 non-null    float64
#  5   AMH(ng/mL)              541 non-null    object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 25.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3     I   beta-HCG(mIU/mL)  541 non-null    float64
#  4   II    beta-HCG(mIU/mL)  541 non-null    float64
#  5   AMH(ng/mL)              541 non-null    object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 25.5+ KB

# %%
# lets name pcos_non_inf- df for simplicity

df1=pcos_non_inf

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     242 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
#  14  Pregnant(Y/N)           541 non-null    int64
#  15  No. of aborptions       541 non-null    int64
#  16    I   beta-HCG(mIU/mL)  541 non-null    float64
#  17  II    beta-HCG(mIU/mL)  541 non-null    object
#  18  FSH(mIU/mL)             541 non-null    float64
#  19  LH(mIU/mL)              541 non-null    float64
#  20  FSH/LH                  9 non-null      float64
#  21  Hip(inch)               541 non-null    int64
#  22  Waist(inch)             541 non-null    int64
#  23  Waist:Hip Ratio         9 non-null      float64
#  24  TSH (mIU/L)             541 non-null    float64
#  25  AMH(ng/mL)              541 non-null    object
#  26  PRL(ng/mL)              541 non-null    float64
#  27  Vit D3 (ng/mL)          541 non-null    float64
#  28  PRG(ng/mL)              541 non-null    float64
#  29  RBS(mg/dl)              541 non-null    float64
#  30  Weight gain(Y/N)        541 non-null    int64
#  31  hair growth(Y/N)        541 non-null    int64
#  32  Skin darkening (Y/N)    541 non-null    int64
#  33  Hair loss(Y/N)          541 non-null    int64
#  34  Pimples(Y/N)            541 non-null    int64
#  35  Fast food (Y/N)         540 non-null    float64
#  36  Reg.Exercise(Y/N)       541 non-null    int64
#  37  BP _Systolic (mmHg)     541 non-null    int64
#  38  BP _Diastolic (mmHg)    541 non-null    int64
#  39  Follicle No. (L)        541 non-null    int64
#  40  Follicle No. (R)        541 non-null    int64
#  41  Avg. F size (L) (mm)    541 non-null    float64
#  42  Avg. F size (R) (mm)    541 non-null    float64
#  43  Endometrium (mm)        541 non-null    float64
#  44  Unnamed: 44             2 non-null      object
# dtypes: float64(19), int64(23), object(3)
# memory usage: 190.3+ KB

# %%
#lets merge the two dataframes
df = pd.merge(df1,df0, on='Patient File No.', suffixes=('','_x'),how='left')
#Dropping the repeated features after merging
df =df.drop([ 'Sl. No_x', 'PCOS (Y/N)_x', '  I   beta-HCG(mIU/mL)_x',
       'II    beta-HCG(mIU/mL)_x', 'AMH(ng/mL)_x'], axis=1)
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1   NaN           15                74                20  ...
# 2   NaN           11                72                18  ...
# 3   NaN           13                72                20  ...
# 4   NaN           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                  0                  110
# 1              0.0                  0                  120
# 2              1.0                  0                  120
# 3              0.0                  0                  120
# 4              0.0                  0                  120
#
#    BP _Diastolic (mmHg)  Follicle No. (L)  Follicle No. (R)  \
# 0                    80                 3                 3
# 1                    70                 3                 5
# 2                    80                13                15
# 3                    70                 2                 2
# 4                    80                 3                 4
#
#    Avg. F size (L) (mm) Avg. F size (R) (mm)  Endometrium (mm)  Unnamed: 44
# 0                  18.0                 18.0               8.5          NaN
# 1                  15.0                 14.0               3.7          NaN
# 2                  18.0                 20.0              10.0          NaN
# 3                  15.0                 14.0               7.5          NaN
# 4                  16.0                 14.0               7.0          NaN
#
# [5 rows x 45 columns]

# %%
#trim column names with extra spaces at start and end positions
df = df.rename(columns=lambda x: x.strip()) 
#verify
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3   Age (yrs)               541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     242 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
#  14  Pregnant(Y/N)           541 non-null    int64
#  15  No. of aborptions       541 non-null    int64
#  16  I   beta-HCG(mIU/mL)    541 non-null    float64
#  17  II    beta-HCG(mIU/mL)  541 non-null    object
#  18  FSH(mIU/mL)             541 non-null    float64
#  19  LH(mIU/mL)              541 non-null    float64
#  20  FSH/LH                  9 non-null      float64
#  21  Hip(inch)               541 non-null    int64
#  22  Waist(inch)             541 non-null    int64
#  23  Waist:Hip Ratio         9 non-null      float64
#  24  TSH (mIU/L)             541 non-null    float64
#  25  AMH(ng/mL)              541 non-null    object
#  26  PRL(ng/mL)              541 non-null    float64
#  27  Vit D3 (ng/mL)          541 non-null    float64
#  28  PRG(ng/mL)              541 non-null    float64
#  29  RBS(mg/dl)              541 non-null    float64
#  30  Weight gain(Y/N)        541 non-null    int64
#  31  hair growth(Y/N)        541 non-null    int64
#  32  Skin darkening (Y/N)    541 non-null    int64
#  33  Hair loss(Y/N)          541 non-null    int64
#  34  Pimples(Y/N)            541 non-null    int64
#  35  Fast food (Y/N)         540 non-null    float64
#  36  Reg.Exercise(Y/N)       541 non-null    int64
#  37  BP _Systolic (mmHg)     541 non-null    int64
#  38  BP _Diastolic (mmHg)    541 non-null    int64
#  39  Follicle No. (L)        541 non-null    int64
#  40  Follicle No. (R)        541 non-null    int64
#  41  Avg. F size (L) (mm)    541 non-null    float64
#  42  Avg. F size (R) (mm)    541 non-null    float64
#  43  Endometrium (mm)        541 non-null    float64
#  44  Unnamed: 44             2 non-null      object
# dtypes: float64(19), int64(23), object(3)
# memory usage: 190.3+ KB

# %%
# convert object columns to float type
df["AMH(ng/mL)"] = pd.to_numeric(df["AMH(ng/mL)"], errors="coerce") 
df["II    beta-HCG(mIU/mL)"] = pd.to_numeric(df["II    beta-HCG(mIU/mL)"], errors="coerce")

# %%
# lets drop all columns that may not be useful to our analysis

df = df.drop(['Unnamed: 44'], axis = 1) 
df = df.drop(['Sl. No'], axis = 1) 
df = df.drop(['Patient File No.'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PCOS (Y/N)              541 non-null    int64
#  1   Age (yrs)               541 non-null    int64
#  2   Weight (Kg)             541 non-null    float64
#  3   Height(Cm)              541 non-null    float64
#  4   BMI                     242 non-null    float64
#  5   Blood Group             541 non-null    int64
#  6   Pulse rate(bpm)         541 non-null    int64
#  7   RR (breaths/min)        541 non-null    int64
#  8   Hb(g/dl)                541 non-null    float64
#  9   Cycle(R/I)              541 non-null    int64
#  10  Cycle length(days)      541 non-null    int64
#  11  Marraige Status (Yrs)   540 non-null    float64
#  12  Pregnant(Y/N)           541 non-null    int64
#  13  No. of aborptions       541 non-null    int64
#  14  I   beta-HCG(mIU/mL)    541 non-null    float64
#  15  II    beta-HCG(mIU/mL)  540 non-null    float64
#  16  FSH(mIU/mL)             541 non-null    float64
#  17  LH(mIU/mL)              541 non-null    float64
#  18  FSH/LH                  9 non-null      float64
#  19  Hip(inch)               541 non-null    int64
#  20  Waist(inch)             541 non-null    int64
#  21  Waist:Hip Ratio         9 non-null      float64
#  22  TSH (mIU/L)             541 non-null    float64
#  23  AMH(ng/mL)              540 non-null    float64
#  24  PRL(ng/mL)              541 non-null    float64
#  25  Vit D3 (ng/mL)          541 non-null    float64
#  26  PRG(ng/mL)              541 non-null    float64
#  27  RBS(mg/dl)              541 non-null    float64
#  28  Weight gain(Y/N)        541 non-null    int64
#  29  hair growth(Y/N)        541 non-null    int64
#  30  Skin darkening (Y/N)    541 non-null    int64
#  31  Hair loss(Y/N)          541 non-null    int64
#  32  Pimples(Y/N)            541 non-null    int64
#  33  Fast food (Y/N)         540 non-null    float64
#  34  Reg.Exercise(Y/N)       541 non-null    int64
#  35  BP _Systolic (mmHg)     541 non-null    int64
#  36  BP _Diastolic (mmHg)    541 non-null    int64
#  37  Follicle No. (L)        541 non-null    int64
#  38  Follicle No. (R)        541 non-null    int64
#  39  Avg. F size (L) (mm)    541 non-null    float64
#  40  Avg. F size (R) (mm)    541 non-null    float64
#  41  Endometrium (mm)        541 non-null    float64
# dtypes: float64(21), int64(21)
# memory usage: 177.6 KB

# %%
# identify columns with missing data

col_missing= df.columns[df.isna().any()].tolist()
col_missing
# Out:
# ['BMI',
#  'Marraige Status (Yrs)',
#  'II    beta-HCG(mIU/mL)',
#  'FSH/LH',
#  'Waist:Hip Ratio',
#  'AMH(ng/mL)',
#  'Fast food (Y/N)']

# %% [markdown]
# > Since missing data is less than 5% for all columns
#
# > Lets impute numeric columns with median and boolean columns with mode

# %%
# Separate numeric columns from boolean columns

# Get the columns with missing values excluding 'Fast food (Y/N)'
col_missing_num = [col for col in df.columns[df.isna().any()].tolist() if col != 'Fast food (Y/N)']

col_missing_boo = [col for col in df.columns[df.isna().any()].tolist() if col not in col_missing_num]

print(col_missing_num)
print(col_missing_boo)
# Out:
# ['BMI', 'Marraige Status (Yrs)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'AMH(ng/mL)']
# ['Fast food (Y/N)']

# %%
# Impute numeric columns with median
for col in col_missing_num:
    df[col].fillna(df[col].median(), inplace=True)

# Impute boolean columns with mode
for col in col_missing_boo:
    df[col].fillna(df[col].mode()[0], inplace=True)
#verify
df.isna().sum()
# Out:
# PCOS (Y/N)                0
# Age (yrs)                 0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     0
# Pregnant(Y/N)             0
# No. of aborptions         0
# I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# Fast food (Y/N)           0
# Reg.Exercise(Y/N)         0
# BP _Systolic (mmHg)       0
# BP _Diastolic (mmHg)      0
# Follicle No. (L)          0
# Follicle No. (R)          0
# Avg. F size (L) (mm)      0
# Avg. F size (R) (mm)      0
# Endometrium (mm)          0
# dtype: int64

# %% [markdown]
# <div style="background-color:#F0F4F7; border-radius:10px; padding:20px;">
#     <h3 style="font-family: Arial, sans-serif; color:#2E4053; text-align:center;">Exploratory Data Analysis</h3>

# %%
sns.set_style("darkgrid")
from warnings import filterwarnings
filterwarnings("ignore")

# %%
#check statistical details 

df.describe()
# Out:
#        PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)         BMI  \
# count  541.000000  541.000000   541.000000  541.000000  541.000000
# mean     0.327172   31.430684    59.637153  156.484835   23.968577
# std      0.469615    5.411006    11.028287    6.033545    2.447450
# min      0.000000   20.000000    31.000000  137.000000   15.100000
# 25%      0.000000   28.000000    52.000000  152.000000   24.000000
# 50%      0.000000   31.000000    59.000000  156.000000   24.000000
# 75%      1.000000   35.000000    65.000000  160.000000   24.000000
# max      1.000000   48.000000   108.000000  180.000000   38.900000
#
#        Blood Group  Pulse rate(bpm)  RR (breaths/min)    Hb(g/dl)  Cycle(R/I)  \
# count   541.000000       541.000000        541.000000  541.000000  541.000000
# mean     13.802218        73.247689         19.243993   11.160037    2.560074
# std       1.840812         4.430285          1.688629    0.866904    0.901950
# min      11.000000        13.000000         16.000000    8.500000    2.000000
# 25%      13.000000        72.000000         18.000000   10.500000    2.000000
# 50%      14.000000        72.000000         18.000000   11.000000    2.000000
# 75%      15.000000        74.000000         20.000000   11.700000    4.000000
# max      18.000000        82.000000         28.000000   14.800000    5.000000
#
#        ...  Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  \
# count  ...    541.000000       541.000000         541.000000
# mean   ...      0.489834         0.515712           0.247689
# std    ...      0.500359         0.500216           0.432070
# min    ...      0.000000         0.000000           0.000000
# 25%    ...      0.000000         0.000000           0.000000
# 50%    ...      0.000000         1.000000           0.000000
# 75%    ...      1.000000         1.000000           0.000000
# max    ...      1.000000         1.000000           1.000000
#
#        BP _Systolic (mmHg)  BP _Diastolic (mmHg)  Follicle No. (L)  \
# count           541.000000            541.000000        541.000000
# mean            114.661738             76.927911          6.129390
# std               7.384556              5.574112          4.229294
# min              12.000000              8.000000          0.000000
# 25%             110.000000             70.000000          3.000000
# 50%             110.000000             80.000000          5.000000
# 75%             120.000000             80.000000          9.000000
# max             140.000000            100.000000         22.000000
#
#        Follicle No. (R)  Avg. F size (L) (mm)  Avg. F size (R) (mm)  \
# count        541.000000            541.000000            541.000000
# mean           6.641405             15.018115             15.451701
# std            4.436889              3.566839              3.318848
# min            0.000000              0.000000              0.000000
# 25%            3.000000             13.000000             13.000000
# 50%            6.000000             15.000000             16.000000
# 75%           10.000000             18.000000             18.000000
# max           20.000000             24.000000             24.000000
#
#        Endometrium (mm)
# count        541.000000
# mean           8.475915
# std            2.165381
# min            0.000000
# 25%            7.000000
# 50%            8.500000
# 75%            9.800000
# max           18.000000
#
# [8 rows x 42 columns]

# %%
# Save file as pcos.csv and further to perform EDA on PowerBI 
df.to_csv('pcos.csv', index=False)

# %%
# Define the age boundaries for the bins
age_bins = [20, 25, 30, 35, 40, 45, 50]

# Create a new column 'Age Group' with the bins
df['Age Group'] = pd.cut(df['Age (yrs)'], bins=age_bins)
df.filtered= df.loc[:,['Age Group', 'Age (yrs)']]
df.filtered.head()
# Out:
#   Age Group  Age (yrs)
# 0  (25, 30]         28
# 1  (35, 40]         36
# 2  (30, 35]         33
# 3  (35, 40]         37
# 4  (20, 25]         25

# %%
sns.countplot(x="Age Group", hue="PCOS (Y/N)", data=df)
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("PCOS Diagnosis by Age Group")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title="PCOS Diagnosis", loc="upper right")
plt.tight_layout()
plt.show()

# %%
# Calculate proportions of PCOS diagnosis in each age group
proportions = df.groupby('Age Group')['PCOS (Y/N)'].value_counts(normalize=True).reset_index(name='Proportion')
proportions
# Out:
#    Age Group  PCOS (Y/N)  Proportion
# 0   (20, 25]           1    0.564516
# 1   (20, 25]           0    0.435484
# 2   (25, 30]           0    0.633880
# 3   (25, 30]           1    0.366120
# 4   (30, 35]           0    0.702381
# 5   (30, 35]           1    0.297619
# 6   (35, 40]           0    0.804348
# 7   (35, 40]           1    0.195652
# 8   (40, 45]           0    0.840000
# 9   (40, 45]           1    0.160000
# 10  (45, 50]           1    0.600000
# 11  (45, 50]           0    0.400000

# %%
# Plot the proportions
sns.barplot(x='Age Group', y='Proportion', hue='PCOS (Y/N)', data=proportions)
plt.xlabel("Age Group")
plt.ylabel("Proportion of PCOS Diagnosis")
plt.title("Proportion of PCOS Diagnosis by Age Group")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title="PCOS Diagnosis", loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# > It seems the proportion of POCS diagnosed postive is much higher in young (20 to 25) and older (45 to 50) age groups
#
# > Note: The older (45 to 50) age group, has very low data to drive any significant relevence.

# %%
# Exclude non-numeric columns from correlation matrix calculation
numeric_columns = df.select_dtypes(include='number').columns.tolist()
df_numeric = df[numeric_columns]

# Calculate the correlation matrix
corr = df_numeric.corr()

# Set the color palette for colorblind-friendly colors
cmap = sns.color_palette("colorblind")

# Create a heatmap
plt.figure(figsize=(18,18))
sns.heatmap(corr, annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of All Features")
plt.show()

# %%
# get correlation coeffient values in descending order
corr["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)                1.000000
# Follicle No. (R)          0.648327
# Follicle No. (L)          0.603346
# Skin darkening (Y/N)      0.475733
# hair growth(Y/N)          0.464667
# Weight gain(Y/N)          0.441047
# Cycle(R/I)                0.401644
# Fast food (Y/N)           0.376183
# Pimples(Y/N)              0.286077
# AMH(ng/mL)                0.264141
# Weight (Kg)               0.211938
# Hair loss(Y/N)            0.172879
# Waist(inch)               0.164598
# Hip(inch)                 0.162297
# BMI                       0.134635
# Avg. F size (L) (mm)      0.132992
# Endometrium (mm)          0.106648
# Avg. F size (R) (mm)      0.097690
# Pulse rate(bpm)           0.091821
# Hb(g/dl)                  0.087170
# Vit D3 (ng/mL)            0.085494
# Height(Cm)                0.068254
# Reg.Exercise(Y/N)         0.065337
# LH(mIU/mL)                0.063879
# FSH/LH                    0.062169
# RBS(mg/dl)                0.048922
# BP _Diastolic (mmHg)      0.038032
# RR (breaths/min)          0.036928
# Blood Group               0.036433
# II    beta-HCG(mIU/mL)    0.012760
# BP _Systolic (mmHg)       0.007942
# PRL(ng/mL)                0.005143
# Waist:Hip Ratio           0.002405
# TSH (mIU/L)              -0.010140
# Pregnant(Y/N)            -0.027565
# I   beta-HCG(mIU/mL)     -0.027617
# FSH(mIU/mL)              -0.030319
# PRG(ng/mL)               -0.043834
# No. of aborptions        -0.057158
# Marraige Status (Yrs)    -0.113056
# Age (yrs)                -0.168513
# Cycle length(days)       -0.178480
# Name: PCOS (Y/N), dtype: float64

# %% [markdown]
# > Lets logically group features and perform further EDA

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)', 'Height(Cm)', 'BMI', 'Blood Group', 'Pulse rate(bpm)', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)', 'Age Group']

# %%
Clinical_measures = df.loc[:,['PCOS (Y/N)','Cycle(R/I)', 'Cycle length(days)','Pulse rate(bpm)',
                           'RR (breaths/min)', 'Hb(g/dl)','Follicle No. (L)', 'Follicle No. (R)',
                           'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)',
                           'Blood Group','BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)']]

# %%
# Create a heatmap for clinical measures
plt.figure(figsize=(6,4))
sns.heatmap(Clinical_measures.corr(), annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of Clinical measures")
plt.show()

# %%
Clinical_measures.corr()["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)              1.000000
# Follicle No. (R)        0.648327
# Follicle No. (L)        0.603346
# Cycle(R/I)              0.401644
# Avg. F size (L) (mm)    0.132992
# Endometrium (mm)        0.106648
# Avg. F size (R) (mm)    0.097690
# Pulse rate(bpm)         0.091821
# Hb(g/dl)                0.087170
# BP _Diastolic (mmHg)    0.038032
# RR (breaths/min)        0.036928
# Blood Group             0.036433
# BP _Systolic (mmHg)     0.007942
# Cycle length(days)     -0.178480
# Name: PCOS (Y/N), dtype: float64

# %%
columns_to_exclude = ['Cycle(R/I)', 'Blood Group']  # categorical columns to exclude

# Filter out columns to include in box plots
columns_to_include = [col for col in Clinical_measures.columns if col not in columns_to_exclude]
#Plotting Box plot for the Clinical_measures
for y in columns_to_include:
      if y != "PCOS (Y/N)":
        sns.boxplot(y=y, x="PCOS (Y/N)", data=Clinical_measures)
        plt.show()

# %% [markdown]
# > From all clinical measures, it looks like features; Follicle No. (R), Follicle No. (L), and  Cycle(R/I) have a significant bearing to PCOS diagnosis
#
# > Lets check across all ages in the dataset

# %%
# Length of menstrual cycle 'Cycle length(days)'' in PCOS vs Normal diagnosis 

ax=sns.lmplot(data=df,x="Age (yrs)",y="Cycle length(days)", hue="PCOS (Y/N)")
plt.show(ax)

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 15))

# Plot the first graph
sns.scatterplot(data=df, x="Age (yrs)", y="Cycle(R/I)", hue="PCOS (Y/N)", ax=ax1)
ax1.set_title('Cycle(R/I) vs Age')

# Plot the second graph
sns.scatterplot(data=df, x="Age (yrs)", y="Follicle No. (R)", hue="PCOS (Y/N)", ax=ax2)
ax2.set_title('Follicle No. (R) vs Age')

# Plot the third graph
sns.scatterplot(data=df, x="Age (yrs)", y="Follicle No. (L)", hue="PCOS (Y/N)", ax=ax3)
ax3.set_title('Follicle No. (L) vs Age')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# > From all clinical measures, it looks like features; Follicle No. (R), Follicle No. (L), and  Cycle(R/I) have a significant bearing to PCOS diagnosis regarless of the ages.Most PCOS diagnosed patients had significantly high numbers of folicles in left and right sides.

# %%
# Lets check for categorical features- Blood group

g = sns.catplot(x="Blood Group", y="PCOS (Y/N)", 
                data=Clinical_measures, kind="bar")

plt.show()

# %% [markdown]
# > There is no clear evidence to suggest blood group has any significant bearing on PCOS diagnosis

# %%
# Lets check for categorical features- Blood group

g = sns.catplot(x='Cycle(R/I)', y="PCOS (Y/N)", 
                data=Clinical_measures, kind="bar")

plt.show()

# %% [markdown]
# > The feature Cylcle(R/I) is not immediately clear from this dataset, but it might stand for "Regular/Irregular" or "Regular/Interval." In the context of PCOS, it likely refers to the regularity of menstrual cycles. "Regular" cycles occur at predictable intervals, while "Irregular" cycles occur at unpredictable intervals or have abnormal characteristics.
#
# > Therefore, "Cycle (R/I)" may indicate whether the individual's menstrual cycles are regular or irregular.
#
# > From this context, PCOS diagnosis  probability seem to be increased with irregular or more menstrual cylcles i.e 4 and 5

# %%
Hormones = df.loc[:,['PCOS (Y/N)','I   beta-HCG(mIU/mL)','II    beta-HCG(mIU/mL)','FSH(mIU/mL)','LH(mIU/mL)','FSH/LH',
                    'AMH(ng/mL)','PRL(ng/mL)','PRG(ng/mL)','Vit D3 (ng/mL)','TSH (mIU/L)']]

# %%
# Create a heatmap for Hormones
plt.figure(figsize=(6,4))
sns.heatmap(Hormones.corr(), annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of Clinical measures")
plt.show()

# %%
Hormones.corr()["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)                1.000000
# AMH(ng/mL)                0.264141
# Vit D3 (ng/mL)            0.085494
# LH(mIU/mL)                0.063879
# FSH/LH                    0.062169
# II    beta-HCG(mIU/mL)    0.012760
# PRL(ng/mL)                0.005143
# TSH (mIU/L)              -0.010140
# I   beta-HCG(mIU/mL)     -0.027617
# FSH(mIU/mL)              -0.030319
# PRG(ng/mL)               -0.043834
# Name: PCOS (Y/N), dtype: float64

# %%
#Plotting Box plot for the Hormones
for y in Hormones:
        if y != "PCOS (Y/N)":
            sns.boxenplot(y=y, x="PCOS (Y/N)", data=Hormones)
            sns.swarmplot(y=y, x="PCOS (Y/N)", data=Hormones,alpha=0.5)
            plt.show()

# %% [markdown]
# > For hormones, it seems AMH has a slight influence to PCOS diagnosis, however more analysis is need to substantiate the significance level of such.

# %%
Physical_attributes= df.loc[:,['PCOS (Y/N)','Weight (Kg)', 'Height(Cm)', 'BMI','Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio'
                               ]]

# %%
# Create a heatmap for Physical_attributes
plt.figure(figsize=(6,4))
sns.heatmap(Physical_attributes.corr(), annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of Clinical measures")
plt.show()

# %%
Physical_attributes.corr()["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)         1.000000
# Weight (Kg)        0.211938
# Waist(inch)        0.164598
# Hip(inch)          0.162297
# BMI                0.134635
# Height(Cm)         0.068254
# Waist:Hip Ratio    0.002405
# Name: PCOS (Y/N), dtype: float64

# %%
#Plotting Box plot for the Physical_attributes
for y in Physical_attributes:
    if y !="PCOS (Y/N)":
        sns.swarmplot(y=y, x="PCOS (Y/N)", data=Physical_attributes, alpha=0.5)
        sns.boxenplot(y=y, x="PCOS (Y/N)", data=Physical_attributes)
        plt.show()

# %% [markdown]
# > It looks like there is no significant evidence of any influence of physical attributes to PCOS diagnosis in this data

# %%
Habits= df.loc[:,['PCOS (Y/N)','Fast food (Y/N)', 'Reg.Exercise(Y/N)','No. of aborptions']]

# %%
# Create a heatmap for Habits
plt.figure(figsize=(6,4))
sns.heatmap(Habits.corr(), annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of Clinical measures")
plt.show()

# %%
Habits.corr()["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)           1.000000
# Fast food (Y/N)      0.376183
# Reg.Exercise(Y/N)    0.065337
# No. of aborptions   -0.057158
# Name: PCOS (Y/N), dtype: float64

# %%
for y in Habits:
    if y != "PCOS (Y/N)":
        if y !="No. of aborptions":
            sns.barplot(y= y, x = "PCOS (Y/N)", data = Habits)
            plt.show()

# %% [markdown]
# > Except for Fast Foods intake, It seems there is no significant evidence of any influence due to habits on PCOS diagnosis in this data

# %%
Clinical_symptoms= df.loc[:,['PCOS (Y/N)','Hair loss(Y/N)', 'Pimples(Y/N)','hair growth(Y/N)',
                             'Skin darkening (Y/N)','Pregnant(Y/N)','Weight gain(Y/N)']]

# %%
# Create a heatmap for Clinical_symptoms
plt.figure(figsize=(6,4))
sns.heatmap(Clinical_symptoms.corr(), annot=False, cmap=cmap)
plt.title("Correlation Matrix Heatmap of Clinical measures")
plt.show()

# %%
Clinical_symptoms.corr()["PCOS (Y/N)"].sort_values(ascending=False)
# Out:
# PCOS (Y/N)              1.000000
# Skin darkening (Y/N)    0.475733
# hair growth(Y/N)        0.464667
# Weight gain(Y/N)        0.441047
# Pimples(Y/N)            0.286077
# Hair loss(Y/N)          0.172879
# Pregnant(Y/N)          -0.027565
# Name: PCOS (Y/N), dtype: float64

# %%
#Plotting barplot for Clinical_symptoms
for x in Clinical_symptoms:
    if x != "PCOS (Y/N)":
        sns.barplot(x= x, y = "PCOS (Y/N)", data = Clinical_symptoms)
        plt.show()

# %% [markdown]
# > Skin darkeing, hair loss and weight gain seem to be the most common symptoms associated with PCOS diagnosed individuals

# %% [markdown]
# <div style="background-color: #F0F4F7; border-radius: 10px; padding: 20px;">
#     <h3 style="font-family: Arial, sans-serif; color: #2E4053; text-align: center;">Model Building</h3>
# </div>

# %%
#Create the features (X)and target(y)

X=df.drop(["PCOS (Y/N)","Age Group"],axis = 1) # drop the age group category column
y=df["PCOS (Y/N)"]

#Split the data into test set 30% and training set 70%

X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,random_state=1)

# %% [markdown]
# <div style="background-color: #F0F4F7; border-radius: 10px; padding: 20px;">
#     <h4 style="font-family: Arial, sans-serif; color: #2E4053; text-align: center;">Classification using Linear Models</h4>
# </div>

# %%
from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import pandas as pd

# Assuming you have already defined X_train, X_test, y_train, and y_test

# Define a list of linear classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Ridge Classifier": RidgeClassifier(),
    "Stochastic Gradient Descent": SGDClassifier(),
    "Linear SVM": LinearSVC()
}

# Loop through each classifier
for name, classifier in classifiers.items():
    print(f"Evaluating {name}:")
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    accuracy = classifier.score(X_test, y_test)
    print(f"Accuracy of {name} Classifier on test set: {accuracy:.2f}")

    conf_matrix = confusion_matrix(y_test, y_pred)
    print('\nThe confusion Matrix is : \n', conf_matrix)

    print('\nThe evaluation parameters are thus : \n', classification_report(y_test, y_pred))
    print("="*50)
# Out:
# Evaluating Logistic Regression:
# Accuracy of Logistic Regression Classifier on test set: 0.87
#
# The confusion Matrix is :
#  [[107   6]
#  [ 15  35]]
#
# The evaluation parameters are thus :
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       113
#            1       0.85      0.70      0.77        50
#
#     accuracy                           0.87       163
#    macro avg       0.87      0.82      0.84       163
# weighted avg       0.87      0.87      0.87       163
#
# ==================================================
# Evaluating Ridge Classifier:
# Accuracy of Ridge Classifier Classifier on test set: 0.90
#
# The confusion Matrix is :
#  [[106   7]
#  [ 10  40]]
#
# The evaluation parameters are thus :
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       113
#            1       0.85      0.80      0.82        50
#
#     accuracy                           0.90       163
#    macro avg       0.88      0.87      0.88       163
# weighted avg       0.89      0.90      0.89       163
#
# ==================================================
# Evaluating Stochastic Gradient Descent:
# Accuracy of Stochastic Gradient Descent Classifier on test set: 0.61
#
# The confusion Matrix is :
#  [[69 44]
#  [19 31]]
#
# The evaluation parameters are thus :
#                precision    recall  f1-score   support
#
#            0       0.78      0.61      0.69       113
#            1       0.41      0.62      0.50        50
#
#     accuracy                           0.61       163
#    macro avg       0.60      0.62      0.59       163
# weighted avg       0.67      0.61      0.63       163
#
# ==================================================
# Evaluating Linear SVM:
# Accuracy of Linear SVM Classifier on test set: 0.87
#
# The confusion Matrix is :
#  [[111   2]
#  [ 20  30]]
#
# The evaluation parameters are thus :
#                precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       113
#            1       0.94      0.60      0.73        50
#
#     accuracy                           0.87       163
#    macro avg       0.89      0.79      0.82       163
# weighted avg       0.87      0.87      0.86       163
#
# ==================================================

# %% [markdown]
# > Lets evaluate the models again, but this time with preprocessing step for standardizing the feaatures
#
# > Create a preprocessing pipeline (preprocessor) that scales the features using StandardScaler. Then create a separate pipeline (model) for each classifier, combining the preprocessing step and the classifier. This ensures that the preprocessing is applied to the data before it's passed to the classifier.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split


# Define a list of linear classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Ridge Classifier": RidgeClassifier(),
    "Stochastic Gradient Descent": SGDClassifier(),
    "Linear SVM": LinearSVC()
}

# Create a preprocessing pipeline with StandardScaler
preprocessor = Pipeline([
    ('scaler', StandardScaler())
])

# Loop through each classifier
for name, classifier in classifiers.items():
    print(f"Evaluating {name}:")
    # Create a pipeline combining the preprocessing step and the classifier
    model = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', classifier)
    ])
    
    # Fit the model
    model.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Calculate accuracy
    accuracy = model.score(X_test, y_test)
    print(f"Accuracy of {name} Classifier on test set: {accuracy:.2f}")

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    print('\nThe confusion Matrix is : \n', conf_matrix)

    # Print classification report
    print('\nThe evaluation parameters are : \n', classification_report(y_test, y_pred))
    print("="*100)
# Out:
# Evaluating Logistic Regression:
# Accuracy of Logistic Regression Classifier on test set: 0.93
#
# The confusion Matrix is :
#  [[108   5]
#  [  7  43]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       113
#            1       0.90      0.86      0.88        50
#
#     accuracy                           0.93       163
#    macro avg       0.92      0.91      0.91       163
# weighted avg       0.93      0.93      0.93       163
#
# ====================================================================================================
# Evaluating Ridge Classifier:
# Accuracy of Ridge Classifier Classifier on test set: 0.90
#
# The confusion Matrix is :
#  [[106   7]
#  [ 10  40]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       113
#            1       0.85      0.80      0.82        50
#
#     accuracy                           0.90       163
#    macro avg       0.88      0.87      0.88       163
# weighted avg       0.89      0.90      0.89       163
#
# ====================================================================================================
# Evaluating Stochastic Gradient Descent:
# Accuracy of Stochastic Gradient Descent Classifier on test set: 0.88
#
# The confusion Matrix is :
#  [[106   7]
#  [ 12  38]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       113
#            1       0.84      0.76      0.80        50
#
#     accuracy                           0.88       163
#    macro avg       0.87      0.85      0.86       163
# weighted avg       0.88      0.88      0.88       163
#
# ====================================================================================================
# Evaluating Linear SVM:
# Accuracy of Linear SVM Classifier on test set: 0.91
#
# The confusion Matrix is :
#  [[107   6]
#  [  8  42]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       113
#            1       0.88      0.84      0.86        50
#
#     accuracy                           0.91       163
#    macro avg       0.90      0.89      0.90       163
# weighted avg       0.91      0.91      0.91       163
#
# ====================================================================================================

# %% [markdown]
# > Perfoming standardization greatly improved our linear models
#
# > The Logistic regression and SVM out performed other models both with accuracy score of 90%

# %% [markdown]
# <div style="background-color: #F0F4F7; border-radius: 10px; padding: 20px;">
#     <h4 style="font-family: Arial, sans-serif; color: #2E4053; text-align: center;">Classification using Non-Linear Models</h4>
# </div>

# %% [markdown]
# > Lets check the performances of non-linear classiffiers

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split



# Define a list of non-linear classifiers
classifiers = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}

# Create a preprocessing pipeline with StandardScaler
preprocessor = Pipeline([
    ('scaler', StandardScaler())
])

# Loop through each classifier
for name, classifier in classifiers.items():
    print(f"Evaluating {name}:")
    
    # Create a pipeline combining the preprocessing step and the classifier
    model = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', classifier)
    ])
    
    # Fit the model
    model.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Calculate accuracy
    accuracy = model.score(X_test, y_test)
    print(f"Accuracy of {name} Classifier on test set: {accuracy:.2f}")

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    print('\nThe confusion Matrix is : \n', conf_matrix)

    # Print classification report
    print('\nThe evaluation parameters are : \n', classification_report(y_test, y_pred))
    print("="*50)
# Out:
# Evaluating Decision Tree:
# Accuracy of Decision Tree Classifier on test set: 0.80
#
# The confusion Matrix is :
#  [[95 18]
#  [14 36]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86       113
#            1       0.67      0.72      0.69        50
#
#     accuracy                           0.80       163
#    macro avg       0.77      0.78      0.77       163
# weighted avg       0.81      0.80      0.81       163
#
# ==================================================
# Evaluating Random Forest:
# Accuracy of Random Forest Classifier on test set: 0.93
#
# The confusion Matrix is :
#  [[110   3]
#  [  8  42]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       113
#            1       0.93      0.84      0.88        50
#
#     accuracy                           0.93       163
#    macro avg       0.93      0.91      0.92       163
# weighted avg       0.93      0.93      0.93       163
#
# ==================================================
# Evaluating Gradient Boosting:
# Accuracy of Gradient Boosting Classifier on test set: 0.93
#
# The confusion Matrix is :
#  [[111   2]
#  [  9  41]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       113
#            1       0.95      0.82      0.88        50
#
#     accuracy                           0.93       163
#    macro avg       0.94      0.90      0.92       163
# weighted avg       0.93      0.93      0.93       163
#
# ==================================================
# Evaluating K-Nearest Neighbors:
# Accuracy of K-Nearest Neighbors Classifier on test set: 0.89
#
# The confusion Matrix is :
#  [[109   4]
#  [ 14  36]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       113
#            1       0.90      0.72      0.80        50
#
#     accuracy                           0.89       163
#    macro avg       0.89      0.84      0.86       163
# weighted avg       0.89      0.89      0.89       163
#
# ==================================================

# %% [markdown]
# > Lets improve our models with hyperparameter tuning
#
# > First we define a parameter grid for each classifier containing the hyperparameters we want to tune. We then loop through each classifier, create a pipeline combining the preprocessing step and the classifier, and define a grid search with cross-validation using GridSearchCV. We fit the grid search to find the best hyperparameters and then use the best model to predict on the test set. Finally, we evaluate the model's performance using accuracy, confusion matrix, and classification report.

# %%
from sklearn.model_selection import GridSearchCV

# Define a parameter grid for each classifier
param_grid = {
    "Decision Tree": {
        "classifier__max_depth": [3, 5, 7, None],
        "classifier__min_samples_split": [2, 5, 10]
    },
    "Random Forest": {
        "classifier__n_estimators": [50, 100, 200],
        "classifier__max_depth": [3, 5, 7, None],
        "classifier__min_samples_split": [2, 5, 10]
    },
    "Gradient Boosting": {
        "classifier__n_estimators": [50, 100, 200],
        "classifier__learning_rate": [0.01, 0.1, 0.2],
        "classifier__max_depth": [3, 5, 7]
    },
    "K-Nearest Neighbors": {
        "classifier__n_neighbors": [3, 5, 7, 10],
        "classifier__weights": ['uniform', 'distance']
    }
}

# Loop through each classifier
for name, classifier in classifiers.items():
    print(f"Evaluating {name}:")
    
    # Create a pipeline combining the preprocessing step and the classifier
    model = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', classifier)
    ])
    
    # Define the grid search with cross-validation
    grid_search = GridSearchCV(model, param_grid[name], cv=5, n_jobs=-1)
    
    # Fit the grid search to find the best hyperparameters
    grid_search.fit(X_train, y_train)
    
    # Get the best hyperparameters
    best_params = grid_search.best_params_
    print("Best Hyperparameters:", best_params)
    
    # Predict on the test set using the best model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    
    # Calculate accuracy
    accuracy = best_model.score(X_test, y_test)
    print(f"Accuracy of {name} Classifier on test set: {accuracy:.2f}")

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    print('\nThe confusion Matrix is : \n', conf_matrix)

    # Print classification report
    print('\nThe evaluation parameters are : \n', classification_report(y_test, y_pred))
    print("="*50)
# Out:
# Evaluating Decision Tree:
# Best Hyperparameters: {'classifier__max_depth': 3, 'classifier__min_samples_split': 2}
# Accuracy of Decision Tree Classifier on test set: 0.84
#
# The confusion Matrix is :
#  [[103  10]
#  [ 16  34]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       113
#            1       0.77      0.68      0.72        50
#
#     accuracy                           0.84       163
#    macro avg       0.82      0.80      0.81       163
# weighted avg       0.84      0.84      0.84       163
#
# ==================================================
# Evaluating Random Forest:
# Best Hyperparameters: {'classifier__max_depth': None, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 50}
# Accuracy of Random Forest Classifier on test set: 0.90
#
# The confusion Matrix is :
#  [[109   4]
#  [ 12  38]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       113
#            1       0.90      0.76      0.83        50
#
#     accuracy                           0.90       163
#    macro avg       0.90      0.86      0.88       163
# weighted avg       0.90      0.90      0.90       163
#
# ==================================================
# Evaluating Gradient Boosting:
# Best Hyperparameters: {'classifier__learning_rate': 0.2, 'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# Accuracy of Gradient Boosting Classifier on test set: 0.90
#
# The confusion Matrix is :
#  [[108   5]
#  [ 11  39]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       113
#            1       0.89      0.78      0.83        50
#
#     accuracy                           0.90       163
#    macro avg       0.90      0.87      0.88       163
# weighted avg       0.90      0.90      0.90       163
#
# ==================================================
# Evaluating K-Nearest Neighbors:
# Best Hyperparameters: {'classifier__n_neighbors': 7, 'classifier__weights': 'uniform'}
# Accuracy of K-Nearest Neighbors Classifier on test set: 0.87
#
# The confusion Matrix is :
#  [[109   4]
#  [ 17  33]]
#
# The evaluation parameters are :
#                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       113
#            1       0.89      0.66      0.76        50
#
#     accuracy                           0.87       163
#    macro avg       0.88      0.81      0.84       163
# weighted avg       0.87      0.87      0.87       163
#
# ==================================================

# %% [markdown]
# > The Random Forest and Gradient Boosting Classifiers are the superior models for this project, both with an accuracy score 0f 93%.
#
# > Suggestions and recommendations are most welcome
#
# > THANK YOU

# %% [markdown]
# <div style="background-color: #F0F4F7; border-radius: 10px; padding: 20px;">
#     <h4 style="font-family: Arial, sans-serif; color: #2E4053; text-align: center;">The End</h4>
# </div>
